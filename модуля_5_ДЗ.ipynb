# %% [markdown]
# <a href="https://colab.research.google.com/github/Ysagi2000/skillfactory/blob/main/%D0%BC%D0%BE%D0%B4%D1%83%D0%BB%D1%8F_5_%D0%94%D0%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import seaborn as sns

# %% [markdown]
# Задание №1. Проведите корреляционный анализ данных из файла 'ex1.csv' по Пирсону

# %%
# считывание файла
df1 = pd.read_csv('ex1.csv')

# %%
# КРИТЕРИЙ 1

# проверка, что все элементы - численного типа
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       500 non-null    float64
#  1   y       500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
# построение гистограмм распределения
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
histplot1 = sns.histplot(
    data=df1,
    x='x',
    bins=30,
    ax=axes[0]
)
histplot1.set_title('X распределение', fontsize=16)
histplot1.set_xlabel('x')

histplot2 = sns.histplot(
    data=df1,
    x='y',
    bins=30,
    ax=axes[1]
)
histplot2.set_title('Y распределение', fontsize=16)
histplot2.set_xlabel('y')
# Out:
# Text(0.5, 0, 'y')

# %%
# построение "ящика с усами" для изучения выбросов
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8))

box1 = sns.boxplot(x='x', data=df1, ax=axes[0])
box1.set_title('Распределение x', fontsize=16)

box2 = sns.boxplot(x='y', data=df1, ax=axes[1])
box2.set_title('Распределение y', fontsize=16)

plt.show()

# %%
# построение диаграммы рассеяния
sns.scatterplot(data=df1, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ## вывод о целесообразности использования корреляции Пирсона с обоснованием на основе предшествующих графиков
# Мое заключение, что корреляция Пирсона здесь имеет место для использования.
# Обе переменные являются числовыми, и их распределение на гистограмме напоминает нормальное.
# Важно отметить, что на диаграмме рассеяния наблюдается линейная взаимосвязь между ними.
# При анализе видно, что при распределение переменных присутствуют выбросы,
# однако, на диаграмме рассеяния они не выглядят существенно отклоняющимися
# от линейной зависимости.

# %%
# КРИТЕРИЙ 2
# расчет коэффициента Пирсона

n = df1.shape[0]
alpha = 0.05
r, p_value = stats.pearsonr(df1['x'], df1['y'])
print('Корреляция (r):', r)
print('P-значение:', p_value)


# Расчет t-критерия
t_score = r * (n - 2)**0.5 / (1 - r**2)**0.5
print('t-score:', t_score)
t_critical = stats.t.ppf(1 - alpha/2, df=n-2)
print('Критический t-score:', t_critical)


# Принятие решения на основе критического t-значения
if np.abs(t_score) > t_critical:
    print("Связь статистически значима")
else:
    print("Нельзя отклонить нулевую гипотезу")

# Проверка p-значения
if p_value < alpha:
    print("Связь статистически значима")
else:
    print("Нельзя отклонить нулевую гипотезу")



# расчет t-критерия
# Принятие решения на основе критического значения t
# Out:
# Корреляция (r): 0.8032321850936787
# P-значение: 3.973859056372262e-114
# t-score: 30.0921291394937
# Критический t-score: 1.9647389829672648
# Связь статистически значима
# Связь статистически значима

# %% [markdown]
# ## вывод о степени корреляции величин и статистической значимости их взаимосвязи
# Коэффициент корреляции получился приблизительно равным 0.8, что говорит о сильной прямой взаимосвязи. t-критерий значительно больше критического, поэтому связь можно считать статистически значимой.

# %% [markdown]
# Задание №2. Проведите корреляционный анализ данных из файла 'ex2.csv' по Спирмену

# %%
# считывание файла
df2 = pd.read_csv('ex2.csv')

# %%
# КРИТЕРИЙ 3

# проверка, что все элементы - численного типа
df2.info()
# построение гистограмм распределения

# построение "ящика с усами" для изучения выбросов

# построение диаграммы рассеяния

# вывод о целесообразности использования корреляции Спирмена с обоснованием на основе предшествующих графиков
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       500 non-null    float64
#  1   y       500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
# построение "ящика с усами" для изучения выбросов

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
histplot1 = sns.histplot(
    data=df2,
    x='x',
    bins=30,
    ax=axes[0]
)
histplot1.set_title('Распределение x', fontsize=16)
histplot1.set_xlabel('x')

histplot2 = sns.histplot(
    data=df2,
    x='y',
    bins=30,
    ax=axes[1]
)
histplot2.set_title('Распределение y', fontsize=16)
histplot2.set_xlabel('y')
# Out:
# Text(0.5, 0, 'y')

# %%
# построение "ящика с усами" для изучения выбросов
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8))

box1 = sns.boxplot(x='x', data=df2, ax=axes[0])
box1.set_title('X Распределение', fontsize=16)

box2 = sns.boxplot(x='y', data=df2, ax=axes[1])
box2.set_title('Y Распределение', fontsize=16)

plt.show()

# %% [markdown]
# ## вывод о целесообразности использования корреляции Спирмена с обоснованием на основе предшествующих графиков
# Обе переменные числовые, однако не нормально распределены, присутствует значительное число выбросов, а взаимосвязь нелинейна. В таких условиях подходит коэффициент Спирмена.

# %%
# КРИТЕРИЙ 4

# расчет коэффициента Спирмена
n = df2.shape[0]
alpha = 0.05
r, p_value = stats.spearmanr(df2['x'], df2['y'])
print('Коэффициент Спирмена (r):', r)
print('P-значение:', p_value)

# расчет t-критерия
if p_value < alpha:
    print("Связь статистически значима")
else:
    print("Нельзя отклонить нулевую гипотезу")
# Out:
# Коэффициент Спирмена (r): 0.6170866283465134
# P-значение: 8.471901488365329e-54
# Связь статистически значима

# %% [markdown]
# ## вывод о степени корреляции величин и статистической значимости их взаимосвязи
# Коэффициент корреляции примерно равен 0.62, что говорит о заметной взаимосвязи.
# При этом значение t-критерия говорит о том, что связь статистически значимаz

# %% [markdown]
# Задание №3. Проведите линейный регрессионный анализ данных из файла 'ex3.csv'

# %%
# считывание файла
df3 = pd.read_csv('ex3.csv')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       20 non-null     float64
#  1   y       20 non-null     float64
# dtypes: float64(2)
# memory usage: 452.0 bytes

# %%
# КРИТЕРИЙ 5

# построение диаграммы рассеяния
sns.scatterplot(data=df3, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Обе переменные числовые. На диаграмме рассеяния видна линейная обратная зависимость и отсутствие критических выбросов. В таких условиях подойдет коэффициент Пирсона.

# %%
# расчет коэффициента Пирсона
n = df3.shape[0]
alpha = 0.05
r, p_value = stats.pearsonr(df3['x'], df3['y'])
print(r, p_value)
# Принятие решения на основе критического значения t
t_score = r*(n-2)**0.5 / (1-r**2)**0.5
print('t-score:', t_score)
t_critical = stats.t.ppf(1 - alpha/2, df = n-2)
print('Critical t-Score:',t_critical)
if np.abs(t_score) > t_critical:
    print("Связь статистически значима")
else:
    print("Нельзя отклонить нулевую гипотезу")

# Принятие решения на основе p-значения
p_value = (1 - stats.t.cdf(np.abs(t_score), df = n-2)) * 2
print('P-Value :',p_value)
if p_value < alpha:
    print("Связь статистически значима")
else:
    print("Нельзя отклонить нулевую гипотезу")
# Out:
# -0.9851417834585032 3.1764533567701482e-15
# t-score: -24.33637478930051
# Critical t-Score: 2.10092204024096
# Связь статистически значима
# P-Value : 3.1086244689504383e-15
# Связь статистически значима

# %%
# КРИТЕРИЙ 6

# расчет коэффициентов линейной регрессии

res = stats.linregress(df3['x'], df3['y'])
slope = res.slope
intercept = res.intercept
r_value = res.rvalue
r_squared = r_value ** 2
p_value = res.pvalue

print(f'Коэффициент наклона: {slope:.3f}, сдвиг: {intercept:.3f}')
print(f'Коэффициент корреляции: {r_value:.3f}, '
      f'коэффициент детерминации: {r_squared:.3f}, '
      f'p-value: {p_value:.3f} (из теста Вальда в предположении, что наклон равен нулю)')
print(f'Уравнение регрессии: Y = {intercept:.3f} + {slope:.3f} * X')

# построение диаграммы рассеяния прогнозных и реальных значений на одном графике

res = stats.linregress(df3['x'], df3['y'])
y_pred = res.intercept + res.slope * df3['x']

plt.figure(figsize=(6, 4))
plt.scatter(df3['x'], df3['y'], label='Исходные данные', color='red')
plt.scatter(df3['x'], y_pred, label='Предсказанные значения', color='green')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Линейная регрессия')
plt.legend()
plt.show()
# Out:
# Коэффициент наклона: -2.339, сдвиг: 5.741
# Коэффициент корреляции: -0.985, коэффициент детерминации: 0.971, p-value: 0.000 (из теста Вальда в предположении, что наклон равен нулю)
# Уравнение регрессии: Y = 5.741 + -2.339 * X

# %%
# КРИТЕРИЙ 7

# расчет средней ошибки аппроксимации
# Вычисление предсказанных значений
y_pred = res.intercept + res.slope * df3['x']
approx_err = np.abs((df3['y'] - y_pred) / df3['y']).mean()
print(f'Средняя ошибка аппроксимации: {approx_err:.4f}')
# Out:
# Средняя ошибка аппроксимации: 0.3526

# %% [markdown]
# Средняя ошибка аппроксимации получилась значительно больше, чем 0.1.
# Это говорит о недостаточности переменной Х для объяснения переменной Y.
# На диаграмме рассеяния прогнозных и реальных значений видно, что отклонения в центре графика минимальны, а к краям увеличивается, что косвенно подтверждает эту гипотезу.

# %%
# КРИТЕРИЙ 8
# расчет F-критерия
F_statistic = (res.rvalue**2 / (1 - res.rvalue**2)) * (n - 2)
F_critical = stats.f.ppf(1 - alpha, 1, n - 1)
print(f'Статистика F: {F_statistic:.4f}, Критическое значение F: {F_critical:.4f}')
# Out:
# Статистика F: 592.2591, Критическое значение F: 4.3807

# %% [markdown]
# ## вывод о статистической значимости уравнения в целом
#
# Так как рассчитанный F-критерий намного больше критического, признаем уравнение статистически значимым.

# %%
# КРИТЕРИЙ 9
# расчет стандартных ошибок коэффициентов регрессии и коэффициента корреляции
print(f'Стандартная ошибка наклона: {res.stderr:.4f}, стандартная ошибка сдвига: {res.intercept_stderr:.4f}')
# расчет t-критерия коэффициентов регрессии и коэффициента корреляции
t_critical = abs(stats.t.ppf(alpha / 2, n - 2))
t_observed = F ** 0.5
print(f'Расчетное значение t-критерия: {t_observed:.4f}, критическое значение t-критерия: {t_critical:.4f}')
# Out:
# Стандартная ошибка наклона: 0.0961, стандартная ошибка сдвига: 0.3755
# Расчетное значение t-критерия: 24.3364, критическое значение t-критерия: 2.1009

# %% [markdown]
# ## вывод о статистической значимости коэффициентов регрессии
# Так как расчетное значение t-критерия для коэффициентов регрессии и корреляции больше
# критического, эти коэффициенты статистически значимы.

# %%
# запись диапазона коэффицентов регрессии
slope_error = t_coef * res.stderr
print(f"Naklon (95%): {res.slope:.3f} +/- {slope_error:.3f}")
intercept_error = t_coef * res.intercept_stderr
print(f"Intercept (95%): {res.intercept:.3f} +/- {intercept_error:.3f}")
# Out:
# Naklon (95%): -2.339 +/- 0.202
# Intercept (95%): 5.741 +/- 0.789

# %%
# КРИТЕРИЙ 10

# Дать предсказание в виде интервальной оценки для y при x0 = 6
x0 = 6
y0 = res.intercept + res.slope * x0
var_o = (y_pred - df3['y'])**2
S0 = (var_o.sum() / (n - 1 - 1))**0.5
delta = S0 * (1 + 1/n + (x0 - df3['x'].mean())**2 / (n * df3['x'].var())) * t_coef
print(f'При x0={x0} y принимает значения в интервале ({y0 - delta:.3f}, {y0 + delta:.3f})')
# Out:
# При x0=6 y принимает значения в интервале (-12.263, -4.325)

# %% [markdown]
# Задание №4. Проведите линейный регрессионный анализ данных из файла 'ex4.csv'

# %%
# считывание файла
df4 = pd.read_csv('ex4.csv')
df4.describe()
# Out:
#               x1         x2           y
# count  20.000000  20.000000   20.000000
# mean    4.234983  20.653247   66.293610
# std     5.365649   5.612606   35.571970
# min    -6.443507  10.526957   -9.893143
# 25%     0.253494  17.281618   42.553666
# 50%     4.668408  21.631761   63.164475
# 75%     9.152888  24.944673   92.805205
# max    13.637973  30.243347  137.003862

# %%
# КРИТЕРИЙ 11

# построение диаграмм рассеяния (x1/y, x2/y, x1/x2)
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(30, 10))

scat1 = sns.scatterplot(x='x1', y='y', data=df4, ax=axes[0])
scat1.set_title('Распределение x1 и y', fontsize=25)
scat1.set_xlabel('x1', fontsize=25)
scat1.set_ylabel('y', fontsize=25)

scat2 = sns.scatterplot(x='x2', y='y', data=df4, ax=axes[1])
scat2.set_title('Распределение x2 и y', fontsize=25)
scat2.set_xlabel('x2', fontsize=25)
scat2.set_ylabel('y', fontsize=25)


scat3 = sns.scatterplot(x='x1', y='x2', data=df4, ax=axes[2])
scat3.set_title('Распределение x1 и x2', fontsize=25)
scat3.set_xlabel('x1', fontsize=25)
scat3.set_ylabel('x2', fontsize=25)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## вывод о корректности использования модели множественной регрессии
# По диаграммам рассеяния можно предположить обратную зависимость y от x1, прямую от x2 и отсутствие корреляции между x1 и x2. При таких условиях модель множественной регрессии должна подойти.

# %%
# расчет коэффициентов корреляции
corr_matrix = df4.corr()
corr_matrix
# Out:
#           x1        x2         y
# x1  1.000000 -0.075013 -0.787807
# x2 -0.075013  1.000000  0.669834
# y  -0.787807  0.669834  1.000000

# %% [markdown]
# ## вывод о необходимости устранения какого-либо фактор
# По матрице корреляции видно сильное влияние на y обоих переменных и при этом практически полное отсутствие корреляции между самими переменными. Это позволяет сделать вывод о том, что не нужно устранять никакой из факторов.а

# %%
# КРИТЕРИЙ 12
# расчет стандартных коэффицентов регрессии
df4 = df4.dropna(subset=['x1', 'x2', 'y'])
x1 = (df4['x1'] - df4['x1'].mean()) / df4['x1'].std()
x2 = (df4['x2'] - df4['x2'].mean()) / df4['x2'].std()
y = (df4['y'] - df4['y'].mean()) / df4['y'].std()

X = np.array([x1, x2]).T
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     1993.
# Date:                Fri, 20 Dec 2024   Prob (F-statistic):           6.90e-21
# Time:                        17:41:01   Log-Likelihood:                 26.749
# No. Observations:                  20   AIC:                            -47.50
# Df Residuals:                      17   BIC:                            -44.51
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.245e-17      0.015   4.05e-15      1.000      -0.033       0.033
# ...

# %%
# КРИТЕРИЙ 13

# расчет коэффициентов "чистой" регрессии
b_x1 = model.params['x1'] * df4['y'].std() / df4['x1'].std()
b_x2 = model.params['x2'] * df4['y'].std() / df4['x2'].std()
a = df4['y'].mean() - (b_x1 * df4['x1'].mean()) - (b_x2 * df4['x2'].mean())
print(f'Коэффициенты чистой регрессии: a = {a}, b_x1 = {b_x1}, b_x2 = {b_x2}')

# построение диаграмм рассеяния прогнозных и реальных значений на одном графике

df4['y_pred'] = a + b_x1 * df4['x1'] + b_x2 * df4['x2']
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))

axes[0].scatter(df4['x1'], df4['y'], color='blue', alpha=0.6, label='Фактические данные')
axes[0].scatter(df4['x1'], df4['y_pred'], color='red', alpha=0.6, label='Предсказанные данные')
axes[0].set_title('Зависимость y от x1', fontsize=16)
axes[0].set_xlabel('x1', fontsize=14)
axes[0].set_ylabel('y', fontsize=14)
axes[0].legend()

axes[1].scatter(df4['x2'], df4['y'], color='blue', alpha=0.6, label='Фактические данные')
axes[1].scatter(df4['x2'], df4['y_pred'], color='red', alpha=0.6, label='Предсказанные данные')
axes[1].set_title('Зависимость y от x2', fontsize=16)
axes[1].set_xlabel('x2', fontsize=14)
axes[1].set_ylabel('y', fontsize=14)
axes[1].legend()

axes[2].scatter(df4['y'], df4['y_pred'], color='green', alpha=1)
axes[2].set_title('Сравнение y и y_pred', fontsize=16)
axes[2].set_xlabel('Фактическое y', fontsize=14)
axes[2].set_ylabel('Предсказанное y (y_pred)', fontsize=14)

plt.tight_layout()  # Сделать макет более компактным
plt.show()
# Out:
# Коэффициенты чистой регрессии: a = 6.722076359546861, b_x1 = -4.917384791357815, b_x2 = 3.892684581539492

# %%
# КРИТЕРИЙ 14

# расчет индекса множественной корреляции
# Получение коэффициентов корреляции для переменных x1 и x2 относительно y
correlation_x1_y = corr_matrix['y']['x1']
correlation_x2_y = corr_matrix['y']['x2']
multiple_regression_index = (model.params.x1 * correlation_x1_y) + (model.params.x2 * correlation_x2_y)
print(f'Индекс множественной регрессии R = {multiple_regression_index:.4f}')

# расчет F-критерия
# Определяем количество наблюдений
num_observations = df4.shape[0]
f_statistic = (R**2 / (1 - R**2)) * ((num_observations - 1 - 2) / 2)
f_critical = stats.f.ppf(1 - 0.05, 2, num_observations - 1 - 2)
print(f'Статистика F = {f_statistic:.4f}, Критическое значение F = {f_critical:.4f}')

# вывод о статистической значимости уравнения в целом
# Out:
# Индекс множественной регрессии R = 0.9958
# Статистика F = 994.2284, Критическое значение F = 3.5915

# %% [markdown]
# ## вывод о статистической значимости уравнения в целом
# Так как рассчитанный F-критерий намного больше критического, признаем уравнение статистически значимым.

# %%
# КРИТЕРИЙ 15

# построение 3D-изображения прогнозных и реальных значений на одном графике
# Создаем пустую фигуру для 3D графика
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(projection='3d')

ax.scatter(df4['x1'], df4['x2'], df4['y'], color='red', label='Реальные значения', alpha=0.6)
ax.scatter(df4['x1'], df4['x2'], df4['y_pred'], color='green', label='Прогнозные значения', alpha=1)

ax.set_xlabel('Переменная x1', fontsize=12)
ax.set_ylabel('Переменная x2', fontsize=12)
ax.set_zlabel('Целевая переменная y', fontsize=12)

ax.set_title('Сравнение реальных и прогнозных значений', fontsize=16)
ax.legend()
plt.show()
